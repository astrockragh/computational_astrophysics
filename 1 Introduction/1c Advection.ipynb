# %% [markdown]
# # 1c Advection

# %% [markdown]
# ### Background

# %% [markdown]
# Advection is a central phenomenon in all kinds of fluid dynamics. To quote Wikipedia: "_In the field of physics, engineering, and earth sciences, advection is the transport of a substance by bulk motion_".
#
# Any property of a gas or fluid, such as color, temperature, density, or even velocity or momentum, may be "advected" by the flow.
#
# One way to think of and understand advection, and its central importance in fluid dynamics, is to consider the difference between studying the behavior of some system in a coordinate system moving with the flow (a _co-moving_ coordinate system), and a stationary one (a _lab-frame_ coordinate system).
#
# Since we are looking at the same phenomenon, the terms that describe the physics (forces, heating / cooling, etc) are the same, and the only difference is apparent, and is due to the motion of the coordinate system.  If what happens is described by $f({\bf r},t)$, then in a system moving with velocity $\bf v$, the same thing is described by $f({\bf r}-{\bf v}t,t)$.
#
# From the derivative chain-rule, the motion gives rise to a difference in partial time derivate $\partial f/\partial t$, which is
#
# \begin{equation}\tag{1}
# - v_x \partial f/\partial x - v_y \partial f/\partial y - v_z \partial f/\partial z = -\,{\bf v} \cdot \nabla f
# \end{equation}

# %% [markdown]
# If, for example, the shape of a function is stationary in the co-moving coordinate system, then in the lab-frame one sees the function shape passing by, with the local value changing slowly where the function is smooth, and rapidly where the function is steep.
#
# ![](Advection.png)

# %% [markdown]
# It is customary to write the partial time derivative in the lab-frame $\partial/\partial t$, while the one in the co-moving frame is written ${\rm D}/{\rm D}t$, so
#
# \begin{equation}\tag{2}
# {\rm D}f/{\rm D}t = \partial f/\partial t + {\bf v \cdot \nabla} f
# \end{equation}

# %% [markdown]
# # Numerical Advection

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Advecting a sine-wave
# We can test numerical advection by introducing a time stepping scheme, for example the second order Adams-Bashforth scheme (this can be thought of as an extrapolation in the derivative, see also the useful wikipedia entry: https://en.wikipedia.org/wiki/Linear_multistep_method ). The method can be derived in many ways, for the second order scheme we can simply match Taylor expansions forward and backwards in time:
#
# \begin{equation}
# f(t + \Delta t) = f(t) + f'(t) \Delta t + {1\over 2}f''(t) \Delta t^2 + O(\Delta t^3)
# \end{equation}
#
# \begin{equation}
# f'(t - \Delta t) \Delta t = f'(t) \Delta t - f''(t) \Delta t^2 + O(\Delta t^3)
# \end{equation}
#
# Multiplying the second equation by $1/2$, isolating $f''(t)$ and subtracting from the first, we find
# \begin{equation}
# f(t + \Delta t) = f(t) + {3\over 2}f'(t) \Delta t - {1\over 2}f'(t-\Delta t) \Delta t + O(\Delta t^3)
# \end{equation}

# %%
def adams_bashforth(f0,f1,dfdt,dt):
    """ 2nd order Adams-Bashforth time stepping scheme:
        f1: function at time t
        f0: function at time t-dt
        dfdt: procedure giving the time derivative
    """
    return f1+dt*(1.5*dfdt(f1)-0.5*dfdt(f0))

# %% [markdown]
# Let us use this to advect the function f(x) with velocity $v$, using a time step equal to `courant*ds/v`, where `ds` is the cell size, and `v` is the velocity amplitude:

# %% [markdown]
# #### Initial condition

# %%
n=16
v=1.0
def coordinates(n):
    ds=2.0*np.pi/n
    x=ds*np.arange(n)
    return ds,x
def IC(x,v,t):
    f=np.sin(x-v*t)
    return f
ds,x=coordinates(n)
f0=IC(x,v,0.0)
plt.plot(x,f0,'-o');

# %% [markdown]
# #### Courant condition
# This routine computes the maximum _wavespeed_ -- simply $v$ for advection -- and sets the timestep such that features in the solution do not propagate more than $C\times\Delta x$, a $C$ fraction of a cell, from one iteration to the next.

# %%
v=1.0
def courant(C,v,ds):
    dt=C/np.max(v/ds)
    return dt
dt=courant(0.2,v,ds)
print('dt={:.4f}'.format(dt))
# Out:
# dt=0.0785

# %% [markdown]
# #### Time derivative procedure:
# Define the derivative operator and use it to construct the time-derivative with a _second order in space_ correct result

# %%
def deriv(f,ds,axis=0,order=2):
    return (np.roll(f,-1,axis)-np.roll(f,+1,axis))/(2.0*ds)
def dfdt(f):
    return -v*deriv(f,ds,0)

# %% [markdown]
# #### 10 time steps
# Let us construct an initial condition, and a _time evolution loop_ that updates the function values according to our PDE describing advection

# %%
n=16
v=1.0
C=0.2
ds,x=coordinates(n)
dt=courant(C,v,ds)
f0=IC(x,v,0.0)                        # set "old time" f0 = f(0)
f1=IC(x,v,dt)                         # set "current time" f1 = f(dt)
plt.plot(f0,'-+')
plt.plot(f1,'-+')
for it in range(9):
    f2=adams_bashforth(f0,f1,dfdt,dt) # calculate new time f(t+dt)
    f0=f1                             # set "old time" f0 == f(t)
    f1=f2                             # set "current time" f1 == f(t+dt) = f2
    plt.plot(f1,'-+',label=it)
plt.legend();

# %% [markdown]
# So, this seems to work pretty well, right?  Looking at the plus symbols, we can see that the sine wave has moved about 2 cells, which is consistent with 10 time steps with 0.2 of a cell per time step.

# %% [markdown]
# So, let's try as many steps as would be needed for a full period; i.e, `n` cells:

# %%
n=16
ds,x=coordinates(n)
dt=courant(C,v,ds)
f0=IC(x,v,0.0)                        # set "old time" f0 = f(0)
f1=IC(x,v,dt)                         # set "current time" f1 = f(dt)
plt.plot(f0)
nt=np.int(n/C+0.5)
print('We need {} steps'.format(nt))
t = dt
for it in range(nt-1):                # do one step less because we start at t = dt
    f2=adams_bashforth(f0,f1,dfdt,dt)
    f0=f1
    f1=f2
    t += dt
print("End time / 2 pi:", t / (2 * np.pi))
plt.plot(f2);
# Out:
# We need 80 steps
# End time / 2 pi: 1.000000000000002

# %% [markdown]
# Close, but not exact, so let's compute a measure of the error:

# %%
f0=IC(x,v,0.0)
RMS2=np.average((f0-f2)**2)**0.5
print('The root-mean-square error is {:.6f}'.format(RMS2))
# Out:
# The root-mean-square error is 0.101364

# %% [markdown]
# Now it's interesting to see how the error varies with the number of points `n`:

# %%
N=[]
RMS2=[]
for n in (16,32,64,128,256):
    ds,x=coordinates(n)
    dt=courant(C,v,ds)
    f0=IC(x,v,0.0)
    f1=IC(x,v,dt)
    nt=np.int(n/C+0.5)
    for it in range(nt-1):
        f2=adams_bashforth(f0,f1,dfdt,dt)
        f0=f1
        f1=f2
    f0=IC(x,v,0.0)
    rms=np.average((f0-f2)**2)**0.5
    N.append(n)
    RMS2.append(rms)
plt.loglog(N,RMS2,'o');

# %% [markdown]
# Let's try and fit a line through, observing that the errors seems to drop with a factor of 4 for each step of 2 in `n`:

# %%
plt.loglog(N,RMS2,'o');
N=np.array(N)
plt.loglog(N,0.1/(N/16.0)**2);

# %% [markdown]
# We conclude that the error drops with $1/n^2 \sim dx^2 \sim dt^2$; i.e., the prodedure is _second order accurate in the resolution_.
#
# Second order accuracy means that after advecting a function a fixed amount of time, with a timestep that is reduced according to the cell size, the error scales as $1/n^2$.

# %% [markdown]
# #### __Task 1:__

# %% [markdown]
# Replace the `deriv()` procedure with your 4th order accurate version, and repeat the computation, but store the error as `RMS4` (so you can plot both in the same plot).
#    * What is the accuracy order of the improved procedure?
#    * The answer may seem surprising (or not).  Discuss!

# %%
def deriv2(f,ds,axis=0,order=2):
    return (8*(np.roll(f,-1,axis)-np.roll(f,+1,axis))-(np.roll(f,-2,axis)-np.roll(f,+2,axis)))/(12.0*ds)
def dfdt2(f):
    return -v*deriv2(f,ds,0)

# %%
N=[]
RMS4=[]
for n in (16,32,64,128,256):
    ds,x=coordinates(n)
    dt=courant(C,v,ds)
    f0=IC(x,v,0.0)
    f1=IC(x,v,dt)
    nt=np.int(n/C+0.5)
    for it in range(nt-1):
        f2=adams_bashforth(f0,f1,dfdt2,dt)
        f0=f1
        f1=f2
    f0=IC(x,v,0.0)
    rms=np.average((f0-f2)**2)**0.5
    N.append(n)
    RMS4.append(rms)
plt.loglog(N,RMS4,'o');

# %%
plt.loglog(N,RMS2,'o');
plt.loglog(N,RMS4,'o');
N=np.array(N)
plt.loglog(N,0.1/(N/16.0)**2);
plt.loglog(N,0.01/(N/16.0)**2);

# %% [markdown]
# # Answer to task 1
#
# So the accuracy becomes better by an order of magnitude but the order itself does not change. My guess is that this is due to the problem being a mix between spatial/temporal accuracy and if the temporal accuracy is 1/n^2 and we change the spatial to 1/n^4, it doesn't change much at high n because the temporal error still dominates. However, as we can see in the plot, at low n, there is still some improvement (first plot point at n=16).
#
# If we change the temporal expression, we could see something different. Note that different methods, depending on the magnitude of the absolute error, dominate different parts of the total error (if t-dependent error is 0.000001/n^2 and x-dependent is 1/n^4, the latter still dominates even at intermediate n).

# %% [markdown]
# ### Errors become visible when advecting a square wave
# So, this seems rather good, then -- one can get very small advection errors, by choosing high spatial order.  But the problem is the dependence of the errors on the number of points in the sine wave.  One can think of the error as an error in _phase_ of the sine wave (there is also an error in amplitude, but the error in phase is more important.

# %% [markdown]
# Errors in amplitude and phase of sin/cos waves translate to _dispersion_ of shapes that has "overtones"; i.e., functions whose Fourier transform contains higher wave numbers.

# %% [markdown]
# #### To illustrate _dispersion_, let's make a square(-ish) wave, for testing:

# %% [markdown]
# Such a wave may be though of as a superposition of sine-waves.  A _Fourier transform_ would give the individual amplitudes

# %%
n=16
ds,x=coordinates(n)
def square_wave(x,v,ds,t,steepness=1.0):
    f=IC(x,v,t)
    return np.tanh((steepness/ds)*f)
f0=square_wave(x,v,ds,0.0)
plt.plot(x,f0,'-o');

# %% [markdown]
# We try to evolve it for 10 time steps again, using a copy & paste of what we did before, just with the `square_wave()` as the initial condition, and plotting only the initial and final states:

# %%
n=16
C=0.2
ds,x=coordinates(n)
dt=courant(C,v,ds)
nt=np.int(n/C+0.5)
f0=square_wave(x,v,ds,0.0)
f1=square_wave(x,v,ds,dt)
plt.plot(f0,'-+',label='initial')
for it in range(nt-1):
    f2=adams_bashforth(f0,f1,dfdt,dt)
    f0=f1
    f1=f2
plt.plot(f2,'-+',label='evolved')
plt.legend();

# %% [markdown]
# The "square" wave has already become pretty distorted!

# %% [markdown]
# Let's repeat this for n=32

# %%
n=32
C=0.2
ds,x=coordinates(n)
dt=courant(C,v,ds)
nt=np.int(n/C+0.5)
f0=square_wave(x,v,ds,0.0)
f1=square_wave(x,v,ds,dt)
plt.plot(f0,'-o',label='initial')
for it in range(nt-1):
    f2=adams_bashforth(f0,f1,dfdt,dt)
    f0=f1
    f1=f2
plt.plot(f2,'-+',label='evolved')
plt.legend();

# %% [markdown]
# The error at the front of the square wave looks exactly the same!  Try with `n=64` and `n=128`, to confirm!

# %%
n=64
C=0.2
ds,x=coordinates(n)
dt=courant(C,v,ds)
nt=np.int(n/C+0.5)
f0=square_wave(x,v,ds,0.0)
f1=square_wave(x,v,ds,dt)
plt.plot(f0,'-o',label='initial')
for it in range(nt-1):
    f2=adams_bashforth(f0,f1,dfdt,dt)
    f0=f1
    f1=f2
plt.plot(f2,'-+',label='evolved')
plt.legend();

# %%
n=2**10
C=0.2
ds,x=coordinates(n)
dt=courant(C,v,ds)
nt=np.int(n/C+0.5)
f0=square_wave(x,v,ds,0.0)
f1=square_wave(x,v,ds,dt)
plt.plot(f0,'-o',label='initial')
for it in range(nt-1):
    f2=adams_bashforth(f0,f1,dfdt,dt)
    f0=f1
    f1=f2
plt.plot(f2,'-+',label='evolved')
plt.legend();

# %% [markdown]
# The result is not encouraging; the error remains essentially the same, which shows that the problem cannot be solver by increasing the number of points.

# %% [markdown]
# ## Comment
#
# This looks amazing and like a Fourier decomposition of the square wave

# %% [markdown]
# #### __Task 2:__ Try using the 4th order derivative

# %% [markdown]
# Try, as above, to replace the 2nd order derivative with the 4th order derivative.  Does the problem go away? Why did we have a problem in the first place (_hint_: think of a square wave as a sum of waves with many different wavelengths)

# %%
n=16
C=0.2
ds,x=coordinates(n)
dt=courant(C,v,ds)
nt=np.int(n/C+0.5)
f0=square_wave(x,v,ds,0.0)
f1=square_wave(x,v,ds,dt)
plt.plot(f0,'-+',label='initial')
for it in range(nt-1):
    #here is the change
    f2=adams_bashforth(f0,f1,dfdt2,dt)
    f0=f1
    f1=f2
plt.plot(f2,'-+',label='evolved')
plt.legend();

# %%
n=2**8
C=0.2
ds,x=coordinates(n)
dt=courant(C,v,ds)
nt=np.int(n/C+0.5)
f0=square_wave(x,v,ds,0.0)
f1=square_wave(x,v,ds,dt)
plt.plot(f0,'-o',label='initial')
for it in range(nt-1):
    #here is the change
    f2=adams_bashforth(f0,f1,dfdt2,dt)
    f0=f1
    f1=f2
plt.plot(f2,'-+',label='evolved')
plt.legend();

# %% [markdown]
# This helps but it doesn't solve the problem. The reason for this is the way the function that creates the step function works. Every time we increase the resolution, making ds smaller, the steepness which goes as 1/ds, makes the square wave more of a step-function. Thus, the number of points on the step stays constant.
#
# This means that the wave we approximate, is essentially just a fourier decomposition, and even though better resolution allows for more, and smaller, different wavelengths, and a more accurate representation of the square in general, we also make it increasingly harder for the wave to be approximated as a function of the resolution. This can be summarized by noting that the nummber of evolved points in the steep part is always the same no matter the grid size in this scheme.
#
# Had we taken the steepness as a constant parameter this would be radically different. Let's see.

# %%
n=16
ds,x=coordinates(n)
def square_wave(x,v,ds,t,steepness=5):
    f=IC(x,v,t)
    return np.tanh((steepness)*f)
f0=square_wave(x,v,ds,0.0)
plt.plot(x,f0,'-o');

# %%
#Let's try with the 2nd order centered derivative first
n=16
C=0.2
ds,x=coordinates(n)
dt=courant(C,v,ds)
nt=np.int(n/C+0.5)
f0=square_wave(x,v,ds,0.0)
f1=square_wave(x,v,ds,dt)
plt.plot(f0,'-+',label='initial')
for it in range(nt-1):
    #here is the change
    f2=adams_bashforth(f0,f1,dfdt,dt)
    f0=f1
    f1=f2
plt.plot(f2,'-+',label='evolved')
plt.legend();

# %%
#Let's try with the 2nd order centered derivative first
n=2**10
C=0.2
ds,x=coordinates(n)
dt=courant(C,v,ds)
nt=np.int(n/C+0.5)
f0=square_wave(x,v,ds,0.0)
f1=square_wave(x,v,ds,dt)
plt.plot(f0,'-+',label='initial')
for it in range(nt-1):
    #here is the change
    f2=adams_bashforth(f0,f1,dfdt,dt)
    f0=f1
    f1=f2
plt.plot(f2,'-+',label='evolved')
plt.legend();

# %% [markdown]
# Much better. Now let's do the 4th order derivative

# %%
#Let's try with the 4th order centered derivative first
n=16
C=0.2
ds,x=coordinates(n)
dt=courant(C,v,ds)
nt=np.int(n/C+0.5)
f0=square_wave(x,v,ds,0.0)
f1=square_wave(x,v,ds,dt)
plt.plot(f0,'-+',label='initial')
for it in range(nt-1):
    #here is the change
    f2=adams_bashforth(f0,f1,dfdt2,dt)
    f0=f1
    f1=f2
plt.plot(f2,'-+',label='evolved')
plt.legend();

# %%
#Let's try with the 2nd order centered derivative first
n=2**9
C=0.2
ds,x=coordinates(n)
dt=courant(C,v,ds)
nt=np.int(n/C+0.5)
f0=square_wave(x,v,ds,0.0)
f1=square_wave(x,v,ds,dt)
plt.plot(f0,'-+',label='initial')
for it in range(nt-1):
    #here is the change
    f2=adams_bashforth(f0,f1,dfdt2,dt)
    f0=f1
    f1=f2
plt.plot(f2,'-+',label='evolved')
plt.legend();

# %% [markdown]
# So this is much much better. Note again, that the number of points on the steep part **does** change. The problem that we cannot efficiently evolve features at the grid scale has been solved.

# %% [markdown]
# #### __Absalon turn-in:__

# %% [markdown]
# Answer the questions in Task 1 and 2 in the notebook and upload the notebook together with a PDF file of the notebook.

# %% [markdown]
# #### __Task 1:__

# %% [markdown]
# Replace the `deriv()` procedure with your 4th order accurate version, and repeat the computation, but store the error as `RMS4` (so you can plot both in the same plot).
#    * What is the accuracy order of the improved procedure?
#    * The answer may seem surprising (or not).  Discuss!

# %%
def deriv2(f,ds,axis=0,order=2):
    return (8*(np.roll(f,-1,axis)-np.roll(f,+1,axis))-(np.roll(f,-2,axis)-np.roll(f,+2,axis)))/(12.0*ds)
def dfdt2(f):
    return -v*deriv2(f,ds,0)

# %%
N=[]
RMS4=[]
for n in (16,32,64,128,256):
    ds,x=coordinates(n)
    dt=courant(C,v,ds)
    f0=IC(x,v,0.0)
    f1=IC(x,v,dt)
    nt=np.int(n/C+0.5)
    for it in range(nt-1):
        f2=adams_bashforth(f0,f1,dfdt2,dt)
        f0=f1
        f1=f2
    f0=IC(x,v,0.0)
    rms=np.average((f0-f2)**2)**0.5
    N.append(n)
    RMS4.append(rms)
plt.loglog(N,RMS4,'o');

# %%
plt.loglog(N,RMS2,'o');
plt.loglog(N,RMS4,'o');
N=np.array(N)
plt.loglog(N,0.1/(N/16.0)**2);
plt.loglog(N,0.01/(N/16.0)**2);

# %% [markdown]
# # Answer to task 1
#
# So the accuracy becomes better by an order of magnitude but the order itself does not change. My guess is that this is due to the problem being a mix between spatial/temporal accuracy and if the temporal accuracy is 1/n^2 and we change the spatial to 1/n^4, it doesn't change much at high n because the temporal error still dominates. However, as we can see in the plot, at low n, there is still some improvement (first plot point at n=16).
#
# If we change the temporal expression, we could see something different. Note that different methods, depending on the magnitude of the absolute error, dominate different parts of the total error (if t-dependent error is 0.000001/n^2 and x-dependent is 1/n^4, the latter still dominates even at intermediate n).

# %% [markdown]
# #### __Task 2:__ Try using the 4th order derivative

# %% [markdown]
# Try, as above, to replace the 2nd order derivative with the 4th order derivative.  Does the problem go away? Why did we have a problem in the first place (_hint_: think of a square wave as a sum of waves with many different wavelengths)

# %%
n=16
C=0.2
ds,x=coordinates(n)
dt=courant(C,v,ds)
nt=np.int(n/C+0.5)
f0=square_wave(x,v,ds,0.0)
f1=square_wave(x,v,ds,dt)
plt.plot(f0,'-+',label='initial')
for it in range(nt-1):
    #here is the change
    f2=adams_bashforth(f0,f1,dfdt2,dt)
    f0=f1
    f1=f2
plt.plot(f2,'-+',label='evolved')
plt.legend();

# %%
n=2**8
C=0.2
ds,x=coordinates(n)
dt=courant(C,v,ds)
nt=np.int(n/C+0.5)
f0=square_wave(x,v,ds,0.0)
f1=square_wave(x,v,ds,dt)
plt.plot(f0,'-o',label='initial')
for it in range(nt-1):
    #here is the change
    f2=adams_bashforth(f0,f1,dfdt2,dt)
    f0=f1
    f1=f2
plt.plot(f2,'-+',label='evolved')
plt.legend();

# %% [markdown]
# This helps but it doesn't solve the problem. The reason for this is the way the function that creates the step function works. Every time we increase the resolution, making ds smaller, the steepness which goes as 1/ds, makes the square wave more of a step-function. Thus, the number of points on the step stays constant.
#
# This means that the wave we approximate, is essentially just a fourier decomposition, and even though better resolution allows for more, and smaller, different wavelengths, and a more accurate representation of the square in general, we also make it increasingly harder for the wave to be approximated as a function of the resolution. This can be summarized by noting that the nummber of evolved points in the steep part is always the same no matter the grid size in this scheme.
#
# Had we taken the steepness as a constant parameter this would be radically different. Let's see.

# %%
n=16
ds,x=coordinates(n)
def square_wave(x,v,ds,t,steepness=5):
    f=IC(x,v,t)
    return np.tanh((steepness)*f)
f0=square_wave(x,v,ds,0.0)
plt.plot(x,f0,'-o');

# %%
#Let's try with the 2nd order centered derivative first
n=16
C=0.2
ds,x=coordinates(n)
dt=courant(C,v,ds)
nt=np.int(n/C+0.5)
f0=square_wave(x,v,ds,0.0)
f1=square_wave(x,v,ds,dt)
plt.plot(f0,'-+',label='initial')
for it in range(nt-1):
    #here is the change
    f2=adams_bashforth(f0,f1,dfdt,dt)
    f0=f1
    f1=f2
plt.plot(f2,'-+',label='evolved')
plt.legend();

# %%
#Let's try with the 2nd order centered derivative first
n=2**10
C=0.2
ds,x=coordinates(n)
dt=courant(C,v,ds)
nt=np.int(n/C+0.5)
f0=square_wave(x,v,ds,0.0)
f1=square_wave(x,v,ds,dt)
plt.plot(f0,'-+',label='initial')
for it in range(nt-1):
    #here is the change
    f2=adams_bashforth(f0,f1,dfdt,dt)
    f0=f1
    f1=f2
plt.plot(f2,'-+',label='evolved')
plt.legend();

# %% [markdown]
# Much better. Now let's do the 4th order derivative

# %%
#Let's try with the 4th order centered derivative first
n=16
C=0.2
ds,x=coordinates(n)
dt=courant(C,v,ds)
nt=np.int(n/C+0.5)
f0=square_wave(x,v,ds,0.0)
f1=square_wave(x,v,ds,dt)
plt.plot(f0,'-+',label='initial')
for it in range(nt-1):
    #here is the change
    f2=adams_bashforth(f0,f1,dfdt2,dt)
    f0=f1
    f1=f2
plt.plot(f2,'-+',label='evolved')
plt.legend();

# %%
#Let's try with the 2nd order centered derivative first
n=2**9
C=0.2
ds,x=coordinates(n)
dt=courant(C,v,ds)
nt=np.int(n/C+0.5)
f0=square_wave(x,v,ds,0.0)
f1=square_wave(x,v,ds,dt)
plt.plot(f0,'-+',label='initial')
for it in range(nt-1):
    #here is the change
    f2=adams_bashforth(f0,f1,dfdt2,dt)
    f0=f1
    f1=f2
plt.plot(f2,'-+',label='evolved')
plt.legend();

# %% [markdown]
# So this is much much better. Note again, that the number of points on the steep part **does** change. The problem that we cannot efficiently evolve features at the grid scale has been solved.
