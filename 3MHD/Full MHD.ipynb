# %% [markdown]
# In this notebook, we will solve the full MHD equations, where the induction equation is coupled to the momentum equation via the Lorentz Force. You are going to use a numerical code that uses a combination of operator splitting, upwind methods, and method of characteristics-constrained transport for MHD.

# %% [markdown]
# # Solving the MHD equations using numerical tools - Introduction to FARGO3D

# %% [markdown]
# #### Cloning the code from a git repository

# %% [markdown]
# First, download the code from its git repository

# %%
# !git clone https://bitbucket.org/fargo3d/public.git ~/fargo3d
# Out:
# Cloning into '/home/jovyan/fargo3d'...
# remote: Counting objects: 540, done.
# remote: Compressing objects: 100% (472/472), done.
# remote: Total 540 (delta 295), reused 170 (delta 64)
# Receiving objects: 100% (540/540), 318.64 KiB | 1.31 MiB/s, done.
# Resolving deltas: 100% (295/295), done.

# %%
# %cd ..
# Out:
# /home/jovyan/work/computational_astrophysics

# %% [markdown]
# Next, we need to compile the source files. We will compile the code with an MHD setup called Orszag-Tang Vortex test (Orszag & Tang 1979).

# %% [markdown]
# #### Building the code (compilation)

# %%
# %cd ~/fargo3d/
# !make clean
# !make SETUP=otvortex #This is the Orszag-Tang Vortex test
# Out:
# /home/jovyan/fargo3d
# rm: cannot remove '../scripts/bound_*.code': No such file or directory
# rm: cannot remove '../bin/*': No such file or directory
#
# Everything has been cleaned
#
# Skipping --
# make[1]: Entering directory '/home/jovyan/fargo3d/bin'
# rm: cannot remove '../scripts/bound_*.code': No such file or directory
# ../src/makefile:610: recipe for target 'clean' failed
# make[1]: [clean] Error 1 (ignored)
# rm: cannot remove '../bin/*': No such file or directory
# ../src/makefile:610: recipe for target 'clean' failed
# make[1]: [clean] Error 1 (ignored)
#
# Everything has been cleaned
#
# make[1]: Leaving directory '/home/jovyan/fargo3d/bin'
# make[1]: Entering directory '/home/jovyan/fargo3d/bin'
#
# Generating rescale.c file
# make[1]: Leaving directory '/home/jovyan/fargo3d/bin'
# make[1]: Entering directory '/home/jovyan/fargo3d/bin'
# Generating bound_code files...
# Generating bound_code files...
# Generating bound_code files...
# CC ../src/LowTasks.c ==> LowTasks.o
# CC ../src/psys.c ==> psys.o
# CC ../src/main.c ==> main.o
# CC ../src/param.c ==> param.o
# CC var.c ==> var.o
# CC ../src/usage.c ==> usage.o
# CC ../src/split.c ==> split.o
# PARSING BOUNDARIES...
# Note: This process can be suppressed by declaring HARDBOUNDARIES in the .opt file.
# CC ../src/comm.c ==> comm.o
# CC ../src/CompPresIso.c ==> CompPresIso.o
# CC ../src/CompPresPoly.c ==> CompPresPoly.o
# CC ../src/boundary.c ==> boundary.o
# CC ../src/checknans.c ==> checknans.o
# CC ../src/vanleer_x_a.c ==> vanleer_x_a.o
# CC ../src/vanleer_x_b.c ==> vanleer_x_b.o
# CC ../src/vanleer_y_a.c ==> vanleer_y_a.o
# CC ../src/vanleer_y_b.c ==> vanleer_y_b.o
# CC ../src/vanleer_z_a.c ==> vanleer_z_a.o
# CC ../src/vanleer_z_b.c ==> vanleer_z_b.o
# CC ../src/divrho.c ==> divrho.o
# CC ../src/transport.c ==> transport.o
# CC ../src/substep3.c ==> substep3.o
# CC ../src/CompPresAd.c ==> CompPresAd.o
# CC ../src/substep2_a.c ==> substep2_a.o
# CC ../src/substep2_b.c ==> substep2_b.o
# CC ../setups/otvortex/condinit.c ==> condinit.o
# CC ../src/output.c ==> output.o
# CC ../src/output2d.c ==> output2d.o
# CC ../src/output_vtk.c ==> output_vtk.o
# CC ../src/output_vtk_merging.c ==> output_vtk_merging.o
# CC ../src/algogas.c ==> algogas.o
# CC ../src/planets.c ==> planets.o
# CC ../src/runge_kutta.c ==> runge_kutta.o
# CC ../src/stockholm.c ==> stockholm.o
# CC ../src/mhd.c ==> mhd.o
# CC ../src/potential.c ==> potential.o
# CC ../src/timeinfo.c ==> timeinfo.o
# CC ../src/allocate.c ==> allocate.o
# CC ../src/defout.c ==> defout.o
# CC ../src/fresh.c ==> fresh.o
# CC ../src/light_global_dev.c ==> light_global_dev.o
# CC ../src/fargo_mhd.c ==> fargo_mhd.o
# CC ../src/substep1_x.c ==> substep1_x.o
# CC ../src/substep1_y.c ==> substep1_y.o
# CC ../src/substep1_z.c ==> substep1_z.o
# CC ../src/compfields.c ==> compfields.o
# CC ../src/advect_shift.c ==> advect_shift.o
# CC ../src/rescale.c ==> rescale.o
# CC ../src/momenta_x.c ==> momenta_x.o
# CC ../src/momenta_y.c ==> momenta_y.o
# CC ../src/momenta_z.c ==> momenta_z.o
# CC ../src/reduction_sum.c ==> reduction_sum.o
# CC ../src/reduction_min.c ==> reduction_min.o
# CC ../src/update_x.c ==> update_x.o
# CC ../src/update_y.c ==> update_y.o
# CC ../src/update_z.c ==> update_z.o
# CC ../src/update_density_x.c ==> update_density_x.o
# CC ../src/update_density_y.c ==> update_density_y.o
# CC ../src/update_density_z.c ==> update_density_z.o
# CC ../src/newvel_x.c ==> newvel_x.o
# CC ../src/newvel_y.c ==> newvel_y.o
# CC ../src/newvel_z.c ==> newvel_z.o
# CC ../src/compute_residual.c ==> compute_residual.o
# CC ../src/change_frame.c ==> change_frame.o
# CC ../src/compute_vmed.c ==> compute_vmed.o
# CC ../src/correct_vtheta.c ==> correct_vtheta.o
# CC ../src/cfl.c ==> cfl.o
# CC ../src/cfl_b.c ==> cfl_b.o
# CC ../src/compute_force.c ==> compute_force.o
# CC ../src/compute_slopes.c ==> compute_slopes.o
# CC ../src/compute_star.c ==> compute_star.o
# CC ../src/compute_emf.c ==> compute_emf.o
# CC ../src/update_magnetic.c ==> update_magnetic.o
# CC ../src/lorentz_force.c ==> lorentz_force.o
# CC ../src/fargo_ppa_a.c ==> fargo_ppa_a.o
# CC ../src/fargo_ppa_b.c ==> fargo_ppa_b.o
# CC ../src/fargo_ppa_c.c ==> fargo_ppa_c.o
# CC ../src/fargo_ppa_d.c ==> fargo_ppa_d.o
# CC ../src/fargo_ppa_d_2d.c ==> fargo_ppa_d_2d.o
# CC ../src/fargo_ppa_steep.c ==> fargo_ppa_steep.o
# CC ../src/vanleerx_ppa.c ==> vanleerx_ppa.o
# CC ../src/dh_boundary.c ==> dh_boundary.o
# CC ../src/cpvel.c ==> cpvel.o
# CC ../src/integrate_emf.c ==> integrate_emf.o
# CC ../src/monitor.c ==> monitor.o
# CC ../src/viscosity.c ==> viscosity.o
# CC ../src/init_stockholm.c ==> init_stockholm.o
# CC ../src/visctensor_cart.c ==> visctensor_cart.o
# CC ../src/addviscosity_cart.c ==> addviscosity_cart.o
# CC ../src/addviscosity_cyl.c ==> addviscosity_cyl.o
# CC ../src/addviscosity_sph.c ==> addviscosity_sph.o
# CC ../src/visctensor_sph.c ==> visctensor_sph.o
# CC ../src/visctensor_cyl.c ==> visctensor_cyl.o
# CC ../src/stretch.c ==> stretch.o
# CC ../src/mon_dens.c ==> mon_dens.o
# CC ../src/mon_momx.c ==> mon_momx.o
# CC ../src/mon_momy.c ==> mon_momy.o
# CC ../src/mon_momz.c ==> mon_momz.o
# CC ../src/mon_torque.c ==> mon_torque.o
# CC ../src/comm_device.c ==> comm_device.o
# CC ../src/checkmute_y.c ==> checkmute_y.o
# CC ../src/checkmute_z.c ==> checkmute_z.o
# CC ../src/mon_reynolds.c ==> mon_reynolds.o
# CC ../src/mon_maxwell.c ==> mon_maxwell.o
# CC ../src/mon_bxflux.c ==> mon_bxflux.o
# CC ../src/postrestarthook.c ==> postrestarthook.o
# CC ../src/change_arch.c ==> change_arch.o
# CC ../src/select_device.c ==> select_device.o
# CC ../src/redefoptions.c ==> redefoptions.o
# CC ../src/setuphook1.c ==> setuphook1.o
# CC ../src/fill_ghostsx.c ==> fill_ghostsx.o
# CC ../src/cfl_fluids_min.c ==> cfl_fluids_min.o
# CC ../src/colrate.c ==> colrate.o
# CC ../src/collisions.c ==> collisions.o
# CC ../src/resetfield.c ==> resetfield.o
# CC ../src/totaldens.c ==> totaldens.o
# CC ../src/floor.c ==> floor.o
# CC ../src/ShearingPeriodicBC.c ==> ShearingPeriodicBC.o
# CC ../src/summary.c ==> summary.o
# CC ../src/dust_diffusion_main.c ==> dust_diffusion_main.o
# CC ../src/dust_diffusion_core.c ==> dust_diffusion_core.o
# CC ../src/dust_diffusion_coefficients.c ==> dust_diffusion_coefficients.o
# CC ../src/copy_field.c ==> copy_field.o
# CC ../src/nimhd_hall_effect.c ==> nimhd_hall_effect.o
# CC ../src/nimhd_hall_effect_emfx.c ==> nimhd_hall_effect_emfx.o
# CC ../src/nimhd_hall_effect_emfy.c ==> nimhd_hall_effect_emfy.o
# CC ../src/nimhd_hall_effect_emfz.c ==> nimhd_hall_effect_emfz.o
# CC ../src/nimhd_hall_effect_updateB.c ==> nimhd_hall_effect_updateB.o
# CC ../src/nimhd_hall_effect_update_emfs.c ==> nimhd_hall_effect_update_emfs.o
# CC ../src/nimhd_hall_effect_coeff.c ==> nimhd_hall_effect_coeff.o
# CC ../src/nimhd_ambipolar_diffusion.c ==> nimhd_ambipolar_diffusion.o
# CC ../src/nimhd_ambipolar_diffusion_emfx.c ==> nimhd_ambipolar_diffusion_emfx.o
# CC ../src/nimhd_ambipolar_diffusion_emfy.c ==> nimhd_ambipolar_diffusion_emfy.o
# CC ../src/nimhd_ambipolar_diffusion_emfz.c ==> nimhd_ambipolar_diffusion_emfz.o
# CC ../src/nimhd_ambipolar_diffusion_coeff.c ==> nimhd_ambipolar_diffusion_coeff.o
# CC ../src/nimhd_ohmic_diffusion.c ==> nimhd_ohmic_diffusion.o
# CC ../src/nimhd_ohmic_diffusion_coeff.c ==> nimhd_ohmic_diffusion_coeff.o
# CC ../src/compute_jx.c ==> compute_jx.o
# CC ../src/compute_jy.c ==> compute_jy.o
# CC ../src/compute_jz.c ==> compute_jz.o
# CC ymin_bound_0.c ==> ymin_bound_0.o
# CC ymax_bound_0.c ==> ymax_bound_0.o
# CC zmin_bound_0.c ==> zmin_bound_0.o
# CC zmax_bound_0.c ==> zmax_bound_0.o
# CC ../src/mpi_dummy.c ==> mpi_dummy.o
#
# All objects are OK. Linking stage
#
#           FARGO3D SUMMARY:
#           ===============
#
# This built is SEQUENTIAL. Use "make para" to change that
#
#
# SETUP:      'otvortex'
# (Use "make SETUP=[valid_setup_string]" to change set up)
# (Use "make list" to see the list of setups implemented)
# (Use "make info" to see the current sticky build options)
#
# rm ymin_bound_0.c
# make[1]: Leaving directory '/home/jovyan/fargo3d/bin'

# %% [markdown]
# ### Running the code (evolve the MHD equations)

# %% [markdown]
# Next, let's run the code

# %%
# !./fargo3d -o "ny=128, nz=128, dt=0.05, ntot=10, outputdir=outputs/otvortex" setups/otvortex/otvortex.par
# Out:
#        !!!! WARNING !!!!
#
# This is a sequential built of the ./fargo3d code
# If you planned to run the MPI-parallel version,
# then you MUST rebuild the executable. In this case,
#  issue:
# make PARALLEL=1 (or make para)
#
# Any subsequent invocation of make will build an MPI version.
#
#
# ===========================
# FARGO3D git version 2.0-16-gceef70c6
# SETUP: 'otvortex'
# ===========================
#
# The default output directory root is ./
# Reading parameters file setups/otvortex/otvortex.par
# Warning : NY is redefined on the command line.
# Warning : NZ is redefined on the command line.
# Warning : NTOT is redefined on the command line.
# Warning : DT is redefined on the command line.
# Warning : OUTPUTDIR is redefined on the command line.
# The output directory is outputs/otvortex/
# Process 0 created the directory outputs/otvortex/
# I do not output the ghost values
# Warning: The Y spacing is linear (default).
# Field2D Reduction2D has been created
# Field Moment_Plus_X has been created
# Field Moment_Minus_X has been created
# Field2D Vxhy has been created
# Field2D Vxhyr has been created
# Field2D Vxhz has been created
# Field2D Vxhzr has been created
# Field2D Nshift has been created
# Field2D Nxhy has been created
# Field2D Nxhz has been created
# Field Moment_Plus_Y has been created
# Field Moment_Minus_Y has been created
# Field Moment_Plus_Z has been created
# Field Moment_Minus_Z has been created
# Field potential has been created
# Field Slope has been created
# Field DivRho has been created
# Field DensStar has been created
# Field Qs has been created
# Field Pressure has been created
# Field Total_Density has been created
# Grids Pressure and QLeft share their storage
# Field QRight has been created
# Field bx has been created
# Field by has been created
# Field bz has been created
# Grids Moment_Plus_Y and B1_star share their storage
# Grids Moment_Minus_Z and B2_star share their storage
# Grids Pressure and V1_star share their storage
# Grids Moment_Minus_X and V2_star share their storage
# Grids Moment_Plus_X and Slope_b1 share their storage
# Grids Moment_Minus_Y and Slope_v1 share their storage
# Grids DensStar and Slope_b2 share their storage
# Grids Qs and Slope_v2 share their storage
# Grids Moment_Plus_Z and Emfx share their storage
# Grids Slope and Emfy share their storage
# Grids DivRho and Emfz share their storage
# Field divb has been created
# Field gasdens has been created
# Field gasenergy has been created
# Field2D VxMed has been created
# Field gasvx has been created
# Field Vx_temp has been created
# Field gasvy has been created
# Field Vy_temp has been created
# Field gasvz has been created
# Field Vz_temp has been created
# OTVORTEX YZ SETUP
# Found 8 communicators
# Standard version with no ghost zones in X
# OUTPUTS 0 at date t = 0.000000 OK
# ............................
# OUTPUTS 1 at date t = 0.050000 OK
# ..............................
# OUTPUTS 2 at date t = 0.100000 OK
# ..............................
# OUTPUTS 3 at date t = 0.150000 OK
# ....................................
# OUTPUTS 4 at date t = 0.200000 OK
# ..............................................
# OUTPUTS 5 at date t = 0.250000 OK
# ...................................................
# OUTPUTS 6 at date t = 0.300000 OK
# ............................................
# OUTPUTS 7 at date t = 0.350000 OK
# .............................................
# OUTPUTS 8 at date t = 0.400000 OK
# ...............................................
# OUTPUTS 9 at date t = 0.450000 OK
# ............................................
# OUTPUTS 10 at date t = 0.500000 OK
# End of the simulation!

# %% [markdown]
# Let's explore the output directory

# %%
ls outputs/otvortex/
# Out:
# bx0.dat   bz0.dat        gasdens7.dat     gasvx7.dat   gasvz7.dat
# bx10.dat  bz10.dat       gasdens8.dat     gasvx8.dat   gasvz8.dat
# bx1.dat   bz1.dat        gasdens9.dat     gasvx9.dat   gasvz9.dat
# bx2.dat   bz2.dat        gasenergy0.dat   gasvy0.dat   IDL.var
# bx3.dat   bz3.dat        gasenergy10.dat  gasvy10.dat  orbit0.dat
# bx4.dat   bz4.dat        gasenergy1.dat   gasvy1.dat   outputgas.dat
# bx5.dat   bz5.dat        gasenergy2.dat   gasvy2.dat   summary0.dat
# bx6.dat   bz6.dat        gasenergy3.dat   gasvy3.dat   summary10.dat
# bx7.dat   bz7.dat        gasenergy4.dat   gasvy4.dat   summary1.dat
# bx8.dat   bz8.dat        gasenergy5.dat   gasvy5.dat   summary2.dat
# bx9.dat   bz9.dat        gasenergy6.dat   gasvy6.dat   summary3.dat
# by0.dat   domain_x.dat   gasenergy7.dat   gasvy7.dat   summary4.dat
# by10.dat  domain_y.dat   gasenergy8.dat   gasvy8.dat   summary5.dat
# by1.dat   domain_z.dat   gasenergy9.dat   gasvy9.dat   summary6.dat
# by2.dat   gasdens0.dat   gasvx0.dat       gasvz0.dat   summary7.dat
# by3.dat   gasdens10.dat  gasvx10.dat      gasvz10.dat  summary8.dat
# by4.dat   gasdens1.dat   gasvx1.dat       gasvz1.dat   summary9.dat
# by5.dat   gasdens2.dat   gasvx2.dat       gasvz2.dat   variables.par
# by6.dat   gasdens3.dat   gasvx3.dat       gasvz3.dat
# by7.dat   gasdens4.dat   gasvx4.dat       gasvz4.dat
# by8.dat   gasdens5.dat   gasvx5.dat       gasvz5.dat
# by9.dat   gasdens6.dat   gasvx6.dat       gasvz6.dat

# %% [markdown]
# The domain of the mesh is stored in the files:
# - domain_x.dat
# - domain_y.dat (it contains 6 ghost zones (3 at the beginning + 3 at the end, used for boundaries)
# - domain_z.dat (it contains 6 ghost zones (3 at the beginning + 3 at the end, used for boundaries)
#
# The hydrodynamics fields are:
# - gasdens%.dat
# - gasvx%.dat
# - gasvy%.dat
# - gasvz%.dat
#
# The magnetic fields are:
# - bx%.dat
# - by%.dat
# - bz%.dat
#
# Setup related files are in "fargo3d/setups/otvortex/"

# %% [markdown]
# The MHD algorithm is in fargo3d/src/mhd.c

# %%
cat src/mhd.c
# Out:
# #include "fargo3d.h"
#
# void ComputeMHD(real dt) {
#
#   // EMF in x
#   FARGO_SAFE(ComputeSlopes(0,0,1,Vy,Slope_v1));
#   FARGO_SAFE(ComputeSlopes(0,0,1,By,Slope_b1));
#   FARGO_SAFE(ComputeSlopes(0,1,0,Vz,Slope_v2));
#   FARGO_SAFE(ComputeSlopes(0,1,0,Bz,Slope_b2));
#
#   FARGO_SAFE(ComputeStar(dt, 0,1,0, 0,0,1, 1, B1_star,V1_star,Slope_b2,Slope_v2,Slope_b1,Slope_v1));
#   FARGO_SAFE(ComputeStar(dt, 0,0,1, 0,1,0, 1, B2_star,V2_star,Slope_b1,Slope_v1,Slope_b2,Slope_v2));
#
#   FARGO_SAFE(ComputeEmf(dt, 1, 0, 0, B1_star, V1_star, B2_star, V2_star));
#
#   // EMF in y
#   FARGO_SAFE(ComputeSlopes(1,0,0,Vz,Slope_v1));
#   FARGO_SAFE(ComputeSlopes(1,0,0,Bz,Slope_b1));
#   FARGO_SAFE(ComputeSlopes(0,0,1,Vx,Slope_v2));
#   FARGO_SAFE(ComputeSlopes(0,0,1,Bx,Slope_b2));
#
#   FARGO_SAFE(ComputeStar(dt, 0,0,1, 1,0,0, 1, B1_star,V1_star,Slope_b2,Slope_v2,Slope_b1,Slope_v1));
#   FARGO_SAFE(ComputeStar(dt, 1,0,0, 0,0,1, 1, B2_star,V2_star,Slope_b1,Slope_v1,Slope_b2,Slope_v2));
#
#   FARGO_SAFE(ComputeEmf(dt, 0, 1, 0, B1_star, V1_star, B2_star, V2_star));
#
#   // EMF in z
#   FARGO_SAFE(ComputeSlopes(0,1,0,Vx,Slope_v1));
#   FARGO_SAFE(ComputeSlopes(0,1,0,Bx,Slope_b1));
#   FARGO_SAFE(ComputeSlopes(1,0,0,Vy,Slope_v2));
#   FARGO_SAFE(ComputeSlopes(1,0,0,By,Slope_b2));
#
#   FARGO_SAFE(ComputeStar(dt, 1,0,0, 0,1,0, 1, B1_star,V1_star,Slope_b2,Slope_v2,Slope_b1,Slope_v1));
#   FARGO_SAFE(ComputeStar(dt, 0,1,0, 1,0,0, 1, B2_star,V2_star,Slope_b1,Slope_v1,Slope_b2,Slope_v2));
#
#   FARGO_SAFE(ComputeEmf(dt, 0, 0, 1, B1_star, V1_star, B2_star, V2_star));
#
#   // ----------------- NON-IDEAL MHD ---------------------
#
# #ifdef OHMICDIFFUSION
#   FARGO_SAFE(OhmicDiffusion());
# #endif
# #ifdef AMBIPOLARDIFFUSION
#   FARGO_SAFE(AmbipolarDiffusion());
# #endif
# #ifdef HALLEFFECT
#   FARGO_SAFE(HallEffect(dt));
# #endif
#   //-------------------------------------------------------
#
# #ifndef PASSIVEMHD
#   FARGO_SAFE(ComputeSlopes(0,1,0,Bx,Slope_b1));
#   FARGO_SAFE(ComputeSlopes(0,1,0,Vx,Slope_v1));
#   FARGO_SAFE(ComputeSlopes(1,0,0,By,Slope_b2));
#   FARGO_SAFE(ComputeSlopes(1,0,0,Vy,Slope_v2));
#   FARGO_SAFE(ComputeStar(dt, 0,1,0, 1,0,0, 0, B1_star,V1_star,Slope_b1,Slope_v1,Slope_b2,Slope_v2));
#   FARGO_SAFE(ComputeSlopes(0,0,1,Bx,Slope_b1));
#   FARGO_SAFE(ComputeSlopes(0,0,1,Vx,Slope_v1));
#   FARGO_SAFE(ComputeSlopes(1,0,0,Bz,Slope_b2));
#   FARGO_SAFE(ComputeSlopes(1,0,0,Vz,Slope_v2));
#   FARGO_SAFE(ComputeStar(dt, 0,0,1, 1,0,0, 0, B2_star,V2_star,Slope_b1,Slope_v1,Slope_b2,Slope_v2));
#   FARGO_SAFE(LorentzForce(dt, B1_star, B2_star, 1, 0, 0));
#   FARGO_SAFE(ComputeSlopes(0,0,1,By,Slope_b1));
#   FARGO_SAFE(ComputeSlopes(0,0,1,Vy,Slope_v1));
#   FARGO_SAFE(ComputeSlopes(0,1,0,Bz,Slope_b2));
#   FARGO_SAFE(ComputeSlopes(0,1,0,Vz,Slope_v2));
#   FARGO_SAFE(ComputeStar(dt, 0,0,1, 0,1,0, 0, B1_star,V1_star,Slope_b1,Slope_v1,Slope_b2,Slope_v2));
#   FARGO_SAFE(ComputeSlopes(1,0,0,By,Slope_b1));
#   FARGO_SAFE(ComputeSlopes(1,0,0,Vy,Slope_v1));
#   FARGO_SAFE(ComputeSlopes(0,1,0,Bx,Slope_b2));
#   FARGO_SAFE(ComputeSlopes(0,1,0,Vx,Slope_v2));
#   FARGO_SAFE(ComputeStar(dt, 1,0,0, 0,1,0, 0, B2_star,V2_star,Slope_b1,Slope_v1,Slope_b2,Slope_v2));
#   FARGO_SAFE(LorentzForce(dt, B1_star, B2_star, 0, 1, 0));
#   FARGO_SAFE(ComputeSlopes(1,0,0,Bz,Slope_b1));
#   FARGO_SAFE(ComputeSlopes(1,0,0,Vz,Slope_v1));
#   FARGO_SAFE(ComputeSlopes(0,0,1,Bx,Slope_b2));
#   FARGO_SAFE(ComputeSlopes(0,0,1,Vx,Slope_v2));
#   FARGO_SAFE(ComputeStar(dt, 1,0,0, 0,0,1, 0, B1_star,V1_star,Slope_b1,Slope_v1,Slope_b2,Slope_v2));
#   FARGO_SAFE(ComputeSlopes(0,1,0,Bz,Slope_b1));
#   FARGO_SAFE(ComputeSlopes(0,1,0,Vz,Slope_v1));
#   FARGO_SAFE(ComputeSlopes(0,0,1,By,Slope_b2));
#   FARGO_SAFE(ComputeSlopes(0,0,1,Vy,Slope_v2));
#   FARGO_SAFE(ComputeStar(dt, 0,1,0, 0,0,1, 0, B2_star,V2_star,Slope_b1,Slope_v1,Slope_b2,Slope_v2));
#   FARGO_SAFE(LorentzForce(dt, B1_star, B2_star, 0, 0, 1));
# #endif
#
# }
#
#
# void ComputeDivergence(Field *CompX, Field *CompY, Field *CompZ){
#   int i,j,k;
#   real *bx,*by,*bz,*d;
#   real *sxj;
#   real *sxk;
#   real *syj;
#   real *syk;
#   real *szj;
#   real *szk;
#
#   INPUT (CompX);
#   INPUT (CompY);
#   INPUT (CompZ);
#   OUTPUT (Divergence);
#
#   bx = CompX->field_cpu;
#   by = CompY->field_cpu;
#   bz = CompZ->field_cpu;
#   d = Divergence->field_cpu;
#
#   sxj = Sxj;
#   sxk = Sxk;
#   syj = Syj;
#   syk = Syk;
#   szj = Szj;
#   szk = Szk;
#
#   i = j = k = 0;
#   for (k=0; k<Nz+2*NGHZ-1; k++) {
#     for (j=0; j<Ny+2*NGHY-1; j++) {
#       for (i=0; i<Nx; i++) {
# 	d[l] = (bx[lxp]-bx[l])*SurfX(j,k);
# 	d[l]+= by[lyp]*SurfY(j+1,k);
# 	d[l]-= by[l]  *SurfY(j,k);
# 	d[l]+= bz[lzp]*SurfZ(j,k+1);
# 	d[l]-= bz[l]  *SurfZ(j,k);
#       }
#     }
#   }
# }

# %% [markdown]
# ### Let's plot some data

# %%
import numpy as np
import matplotlib.pyplot as plt
#Some customization
plt.rcParams['figure.figsize'] = (5, 5)
plt.rcParams['image.origin']   = 'lower'

# %% [markdown]
# We first create a class that will be useful to obtain the parameters used for each run.

# %%
class Parameters():
    """
    Class for reading the simulation parameters (taken from utils/python/parameters.py).
    input: string -> name of the parfile, normally variables.par
    """
    def __init__(self, directory=''):
        if len(directory) > 1:
            if directory[-1] != '/':
                directory += '/'
        try:
            params = open(directory+"variables.par",'r') #Opening the parfile
        except IOError:                  # Error checker.
            print("Check your directory.")
            return
        lines = params.readlines()     # Reading the parfile
        params.close()                 # Closing the parfile
        par = {}                       # Allocating a dictionary
        for line in lines:             # Iterating over the parfile
            name, value = line.split() # Spliting the name and the value (first blank)
            try:
                float(value)           # First trying with float
            except ValueError:         # If it is not float
                try:
                    int(value)         #                   we try with integer
                except ValueError:     # If it is not integer, we know it is string
                    value = '"' + value + '"'
            par[name] = value          # Filling the dictionary
        for name in par:               # Iterating over the dictionary
            exec("self."+name.lower()+"="+par[name]) # Making the atributes at runtime
            
def get_data(fieldname,n,params):
    """
    We load some scalar field (e.g., density, vx, Bx, etc...)
    and make it 2D (because for this exercise all our fields are 2D).
    """
    return np.fromfile(params.outputdir+fieldname+str(n)+".dat").reshape(params.nz,params.ny)

# %% [markdown]
# Example of use

# %%
params = Parameters("outputs/otvortex/")

# In the notebook, if you now write params and press tab, 
# the autocompletion will show you all the parameters used 
# for the run
density = get_data("gasdens",10,params)
extent  = [params.ymin,params.ymax,params.zmin,params.zmax]
plt.imshow(density,extent=extent)
plt.xlabel("Y")
plt.ylabel("Z")
plt.show()

# %% [markdown]
# ### Task 1: For the Orszag-Tang Vortex test, plot $B_y$, $B_z$, $V_y$ and $V_z$ for $t=0.5$

# %%
#Plotting initial conditions
plt.figure(figsize=(10,10))
params = Parameters("outputs/otvortex/")

for i,name in enumerate(["gasvy","gasvz","by","bz"]):
    plt.subplot(2,2,i+1)
    plt.title(name)
    var = get_data(name,0,params)
    extent  = [params.ymin,params.ymax,params.zmin,params.zmax]
    plt.imshow(var,extent=extent)
    #Get data and plot it

plt.colorbar()

# %%
#Plotting at t=0.5, equal to key 10
plt.figure(figsize=(10,10))
params = Parameters("outputs/otvortex/")

for i,name in enumerate(["gasvy","gasvz","by","bz"]):
    plt.subplot(2,2,i+1)
    plt.title(name)
    var = get_data(name,10,params)
    extent  = [params.ymin,params.ymax,params.zmin,params.zmax]
    plt.imshow(var,extent=extent)
    #Get data and plot it

# %% [markdown]
# Absolutely stunningly beautiful

# %% [markdown]
# ### Task 2: For the Orszag-Tang Vortex test, plot the streamlines and the magnetic lines

# %%
#We need the domain
n = 10

vy = get_data('gasvy',n,params)
vz = get_data('gasvz',n,params)
by = get_data('by',n,params)
bz = get_data('bz',n,params)

outputdir = params.outputdir

# We need a mesh with the domain for the task

# First, load the 1D arrays with the domain
y_1d  = np.loadtxt(params.outputdir+"domain_y.dat")[3:-4]
z_1d  = np.loadtxt(params.outputdir+"domain_z.dat")[3:-4]

# Now, create a 2D mesh using meshgrid
y_2d,z_2d = np.meshgrid(y_1d,z_1d)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title("Magnetic lines")
plt.imshow(density,extent=[params.ymin,params.ymax,params.zmin,params.zmax])
plt.streamplot(y_1d, z_1d, by, bz, color='k', linewidth=0.4)

plt.subplot(1,2,2)
plt.title("Streamlines")
plt.imshow(density,extent=[params.ymin,params.ymax,params.zmin,params.zmax])
plt.streamplot(y_1d, z_1d, vy, vz, color='k', linewidth=0.4);

# %% [markdown]
# ### Task 3: Calculate $\nabla \cdot {\bf B}$, plot it with imshow and verify $\nabla \cdot {\bf B} = 0$ for all the mesh. Consider the solution at $t = 0.5$
#
# $\nabla \cdot {\bf B} = \partial_x B_x + \partial_y B_y + \partial_z B_z$, which in finite differences it reads:
#
# In this problem, $B_x = 0$, so:
# \begin{equation}
# \nabla \cdot {\bf B} = \frac{{B_y}_{jk}-{B_y}_{j-1k}}{\Delta y} + \frac{{B_z}_{jk}-{B_z}_{jk-1}}{\Delta z}
# \end{equation}
#
# Tip: remember that $\Delta y$ and $\Delta z$ are constant, so, if the divergence is zero, then you only need to show that:
# \begin{equation}
# {B_y}_{jk}-{B_y}_{j-1k} + {B_z}_{jk}-{B_z}_{jk-1} = 0
# \end{equation}

# %%
n  = 10
by = get_data('by',n,params)
bz = get_data('bz',n,params)

divB = by-np.roll(by, -1, axis=1)+bz-np.roll(bz, -1, axis=0)
plt.imshow(divB)
plt.colorbar()

# %% [markdown]
# We covered the basics of the code. You can find further documentation in https://fargo3d.bitbucket.io/, and the algorithms used in https://ui.adsabs.harvard.edu/abs/2016ApJS..223...11B/abstract
#
# ---------------------

# %% [markdown]
# ### Linear MRI test
#
# You are going to learn how to use FARGO3D to measure the growth rate of the magnetorotational instability (MRI) and compare it to the values predicted by linear perturbation analysis.
#
# The methods and results of this exercise not only validates the correctness of the solver implemented in a numerical code but also serve as a starting point for studying the so-called nonlinear regime of the MRI.
#
# ### Preliminaries
#
# The magnetorotational instability (MRI) can be derived using the shearing-sheet approximation, which consists of a local expansion of the equations around a fiducial radius in a rotating frame within a disk.
#
# This treatment allows us to neglect the curvature terms and simplify the equations while maintaining important physical properties of the system (like the shear and non-inertial forces in the case of an astrophysical disk).
#
# In order to derive the equations leading to the MRI, we linearize the Navier-Stokes + Induction equations in the incompressible limit ($\nabla \cdot {\bf v}$) = 0 over a constant background magnetic field along the vertical direction $z$ and a constant sheared background (see, e.g. chapter 14.9 from the Theoretical Astrophysics course for more details). We only assume perturbations in the plane.
#
# After writing the perturbations in Fourier space ($\delta \propto \hat{\delta} e^{ik z+\omega t}$), we get the following set of equations for the perturbations:
#
# \begin{align}
# \tilde{\omega} \delta v_x  &= 2 \delta v_y + i\tilde{k}\delta b_x, \nonumber \\
# \tilde{\omega} \delta v_y  &= -\frac{1}{2} \delta v_x + i\tilde{k} \delta b_y, \nonumber \\
# \tilde{\omega} \delta b_x &= i\tilde{k}\delta v_x, \nonumber \\
# \tilde{\omega} \delta b_y  &= -\frac{3}{2} \delta b_x + i\tilde{k} \delta v_y,\nonumber \\ \nonumber
# \end{align}
#
# where $\delta b_{x,y}$ = $\delta B_{x,y}/\sqrt{\mu_0\rho}$, $\tilde{k} = k v_A/\Omega_0$ with $v_A = B_z/\sqrt{\mu_0\rho}$ the Alfvén speed and $\tilde{\omega} = \omega/\Omega_0$. For simplicity, we have omitted the "hat" symbols, but remember that perturbations correspond to the Fourier components (which are in general complex quantities).
#
# By defining the vector $\vec{\delta} \equiv [\delta v_x, \delta v_y, \delta b_x, \delta b_y]$, the system can be written as:
#
# \begin{equation}
# L\delta = \tilde{\omega} \delta
# \end{equation}
# with $L$ given by:
#
# \begin{equation}
# L=
# \begin{bmatrix}
# 0 & 2 & i\tilde{k} & 0 \\
# -1/2 & 0 & 0 & i\tilde{k} \\
# i\tilde{k} & 0 & 0 & 0 \\
# 0 & i\tilde{k} & -3/2 & 0 \\
# \end{bmatrix},
# \end{equation}
#
# In this way, we have reduced the problem to an eigenvalue problem (whose solution gives us the dispersion relation  of the problem, i.e., the pair $k,\omega$ such that non-trivial solution for the perturbations exists.

# %% [markdown]
# #### Dispersion relation
#
# The characteristic equation ($\det(L-\omega I) = 0$) is:
#
# \begin{equation}
# \omega^4+\left(2\tilde{k}^2 + 1\right) \omega^2 + \tilde{k}^2\left(\tilde{k}^2 - 3 \right) = 0 .
# \end{equation}
#
# This is a parabola in $\omega^2$ and the (4) roots are:
#
# \begin{equation}
# \omega = \pm\left[ -\frac{1 + 2\tilde{k}^2}{2} \pm \frac{1}{2}\sqrt{1+16\tilde{k}^{2}}\right]^{1/2}.
# \end{equation}
#
# One of these eigenvalues is real and positive (under conditions you can easily determine), leading to an exponential growth of the perturbations. This exponential growth is called the Magnetorotational instability.
#
# The unstable eigenvalue is:
#
# \begin{equation}
# {\omega_{\rm unstable}} = \left[ -\frac{1 + 2\tilde{k}^2}{2} + \frac{1}{2}\sqrt{1+16\tilde{k}^{2}}\right]^{1/2}
# \end{equation}

# %% [markdown]
# ### Task 1
#
# - Plot the dispersion relation of the instability (i.e., growth rate ($\omega_{\rm unstable}$) as a function of $\tilde{k}$ (assume $\tilde{k}>0$).
#
# - Show that the maximum growth rate occurs at $\tilde{k}_\text{max} = \sqrt{15}/4$ and prove that it is equal to $\omega_\text{max} = 3/4$.
#
# - Show that there is a cut-off at $\tilde{k}_\text{cut-off} = \sqrt{3}$ (i.e., for $\tilde{k}>\tilde{k}_{\rm cut-off}$, $\omega_{\rm unstable}$ is not real anymore).

# %%
def omega_unstable(k, plot=False): 
    omega=np.sqrt(-(1+2*k**2)/2+0.5*np.sqrt(1+16*k**2))
    if plot:
        fig, ax=plt.subplots(figsize=(9,9))
        ax.plot(k, omega, 'k', label='Dispersion relation')
        ax.set(xlabel='k', ylabel=r'$\omega_{unstable}$')
        ax.vlines(np.sqrt(15)/4, 0, max(omega), color='r', linestyle='dashed', label='maximum growth (k)')
        ax.hlines(3/4, 0, max(k), linestyle='dashed', color='r', label=r'maximum growth ($\omega$)')
        ax.legend()
    return omega

# %%
omega_unstable(np.linspace(0, np.sqrt(3), 1000), plot=1);

# %% [markdown]
# ### Evolution of an isolated mode
#
# Once the eigenvalues of the operator $L$ are known, the eigenvectors can be obtained (for each eigenvalue), and the linear solution of the system, for each particular mode, can be written as:
# \begin{align}
# \delta v_x(z,t)  &= \frac{A}{N} \tilde{\omega} \sin{\left(kz\right)} e^{\omega t} \nonumber \\
# \delta v_y(z,t)   &= \frac{A}{N} \frac{\tilde{\omega}^2 + \tilde{k}^2}{2} \sin{\left(kz\right)} e^{\omega t} \nonumber  \\
# \delta b_x(z,t)  &= \frac{A}{N}\tilde{k} \cos{\left(kz\right)} e^{\omega t} \nonumber \\
# \delta b_y(z,t)  &= -\frac{A}{N} \frac{2\tilde{k}\tilde{\omega}}{\tilde{\omega}^2 + \tilde{k}^2} \cos{\left(kz\right)} e^{\omega t} \nonumber
# \end{align}
#
# where $N$ is a normalization factor for the eigenvectors, given by
#
# \begin{equation}
# N = \sqrt{\tilde{\omega}^2 + \left(\frac{\tilde{\omega}^2 + \tilde{k}^2}{2}\right)^2 + \tilde{k}^2 + \left(\frac{2\tilde{k}\tilde{\omega}}{\tilde{\omega}^2 + \tilde{k}^2}\right)^2}
# \end{equation}
#
# The initial amplitude of the perturbations is given by $A$. (Note: the solution for any arbitrary initial condition is can now be obtained as the linear combination of these four modes)
#
#
# ### Task 2 - Using FARGO3D, measure the linear growth rate $\omega$ of the MRI for different values of $\tilde{k}$
#
# Now we will recover the evolution of the unstable mode by solving the full set of nonlinear MHD equations from very small perturbations, so the linear approximation remains valid. In other words, the goal of the exercise is to use FARGO3D to build the dispersion relation numerically, exciting the unstable mode to measure the corresponding growth rate.

# %% [markdown]
# ### Guideline

# %% [markdown]
# #### Step 1 - Incorporating a new setup
#
# Copy the file "mri-growth-sb.tar.gz" to fargo3d/setups/
# and unpack the file (right click, Unpack), after that, you can compile the code with the new setup:

# %% [markdown]
# We first clean the code (remove the executable and compiled sources that were used for the previous setup)

# %%
# !make clean
# Out:
# Everything has been cleaned

# %%
# !cp -f ~/work/computational_astrophysics/3MHD/mri-growth-sb.zip ~/fargo3d/setups/

# %%
cd ~/fargo3d/setups
# Out:
# /home/jovyan/fargo3d/setups

# %%
# !unzip -f ~/fargo3d/setups/mri-growth-sb.zip
# Out:
# Archive:  /home/jovyan/fargo3d/setups/mri-growth-sb.zip

# %% [markdown]
# And compile the code again, but with the new setup "mri-growth-sb"

# %%
# !make SETUP=mri-growth-sb
# Out:
# Skipping --
# make[1]: Entering directory '/home/jovyan/fargo3d/bin'
#
# Generating rescale.c file
# Warning ! Scaling rule not found for SOUNDSPEED. Is it dimensionless ?
# Warning ! Scaling rule not found for BETA. Is it dimensionless ?
# Warning ! Scaling rule not found for AMPLITUDE. Is it dimensionless ?
# Warning ! Scaling rule not found for SHEARPARAM. Is it dimensionless ?
# make[1]: Leaving directory '/home/jovyan/fargo3d/bin'
# make[1]: Entering directory '/home/jovyan/fargo3d/bin'
# Generating bound_code files...
# Generating bound_code files...
# Generating bound_code files...
# CC ../src/LowTasks.c ==> LowTasks.o
# CC ../src/psys.c ==> psys.o
# CC ../src/param.c ==> param.o
# CC ../src/main.c ==> main.o
# CC var.c ==> var.o
# CC ../src/usage.c ==> usage.o
# CC ../src/split.c ==> split.o
# PARSING BOUNDARIES...
# Note: This process can be suppressed by declaring HARDBOUNDARIES in the .opt file.
# Warning: Z boundaries are not defined.
# CC ../src/comm.c ==> comm.o
# CC ../src/CompPresIso.c ==> CompPresIso.o
# CC ../src/CompPresPoly.c ==> CompPresPoly.o
# CC ../src/boundary.c ==> boundary.o
# CC ../src/checknans.c ==> checknans.o
# CC ../src/vanleer_x_a.c ==> vanleer_x_a.o
# CC ../src/vanleer_x_b.c ==> vanleer_x_b.o
# CC ../src/vanleer_y_a.c ==> vanleer_y_a.o
# CC ../src/vanleer_y_b.c ==> vanleer_y_b.o
# CC ../src/vanleer_z_a.c ==> vanleer_z_a.o
# CC ../src/vanleer_z_b.c ==> vanleer_z_b.o
# CC ../src/divrho.c ==> divrho.o
# CC ../src/transport.c ==> transport.o
# CC ../src/substep3.c ==> substep3.o
# CC ../src/CompPresAd.c ==> CompPresAd.o
# CC ../src/substep2_a.c ==> substep2_a.o
# CC ../src/substep2_b.c ==> substep2_b.o
# CC ../setups/mri-growth-sb/condinit.c ==> condinit.o
# CC ../src/output.c ==> output.o
# CC ../src/output2d.c ==> output2d.o
# CC ../src/output_vtk.c ==> output_vtk.o
# CC ../src/output_vtk_merging.c ==> output_vtk_merging.o
# CC ../src/algogas.c ==> algogas.o
# CC ../src/planets.c ==> planets.o
# CC ../src/runge_kutta.c ==> runge_kutta.o
# CC ../src/stockholm.c ==> stockholm.o
# CC ../src/mhd.c ==> mhd.o
# CC ../src/potential.c ==> potential.o
# CC ../src/timeinfo.c ==> timeinfo.o
# CC ../src/allocate.c ==> allocate.o
# CC ../src/defout.c ==> defout.o
# CC ../src/fresh.c ==> fresh.o
# CC ../src/light_global_dev.c ==> light_global_dev.o
# CC ../src/fargo_mhd.c ==> fargo_mhd.o
# CC ../src/substep1_x.c ==> substep1_x.o
# CC ../src/substep1_y.c ==> substep1_y.o
# CC ../src/substep1_z.c ==> substep1_z.o
# CC ../src/compfields.c ==> compfields.o
# CC ../src/advect_shift.c ==> advect_shift.o
# CC ../src/rescale.c ==> rescale.o
# CC ../src/momenta_x.c ==> momenta_x.o
# CC ../src/momenta_y.c ==> momenta_y.o
# CC ../src/momenta_z.c ==> momenta_z.o
# CC ../src/reduction_sum.c ==> reduction_sum.o
# CC ../src/reduction_min.c ==> reduction_min.o
# CC ../src/update_x.c ==> update_x.o
# CC ../src/update_y.c ==> update_y.o
# CC ../src/update_z.c ==> update_z.o
# CC ../src/update_density_x.c ==> update_density_x.o
# CC ../src/update_density_y.c ==> update_density_y.o
# CC ../src/update_density_z.c ==> update_density_z.o
# CC ../src/newvel_x.c ==> newvel_x.o
# CC ../src/newvel_y.c ==> newvel_y.o
# CC ../src/newvel_z.c ==> newvel_z.o
# CC ../src/compute_residual.c ==> compute_residual.o
# CC ../src/change_frame.c ==> change_frame.o
# CC ../src/compute_vmed.c ==> compute_vmed.o
# CC ../src/correct_vtheta.c ==> correct_vtheta.o
# CC ../src/cfl.c ==> cfl.o
# CC ../src/cfl_b.c ==> cfl_b.o
# CC ../src/compute_force.c ==> compute_force.o
# CC ../src/compute_slopes.c ==> compute_slopes.o
# CC ../src/compute_star.c ==> compute_star.o
# CC ../src/compute_emf.c ==> compute_emf.o
# CC ../src/update_magnetic.c ==> update_magnetic.o
# CC ../src/lorentz_force.c ==> lorentz_force.o
# CC ../src/fargo_ppa_a.c ==> fargo_ppa_a.o
# CC ../src/fargo_ppa_b.c ==> fargo_ppa_b.o
# CC ../src/fargo_ppa_c.c ==> fargo_ppa_c.o
# CC ../src/fargo_ppa_d.c ==> fargo_ppa_d.o
# CC ../src/fargo_ppa_d_2d.c ==> fargo_ppa_d_2d.o
# CC ../src/fargo_ppa_steep.c ==> fargo_ppa_steep.o
# CC ../src/vanleerx_ppa.c ==> vanleerx_ppa.o
# CC ../src/dh_boundary.c ==> dh_boundary.o
# CC ../src/cpvel.c ==> cpvel.o
# CC ../src/integrate_emf.c ==> integrate_emf.o
# CC ../src/monitor.c ==> monitor.o
# CC ../src/viscosity.c ==> viscosity.o
# CC ../src/init_stockholm.c ==> init_stockholm.o
# CC ../src/visctensor_cart.c ==> visctensor_cart.o
# CC ../src/addviscosity_cart.c ==> addviscosity_cart.o
# CC ../src/addviscosity_cyl.c ==> addviscosity_cyl.o
# CC ../src/addviscosity_sph.c ==> addviscosity_sph.o
# CC ../src/visctensor_sph.c ==> visctensor_sph.o
# CC ../src/visctensor_cyl.c ==> visctensor_cyl.o
# CC ../src/stretch.c ==> stretch.o
# CC ../src/mon_dens.c ==> mon_dens.o
# CC ../src/mon_momx.c ==> mon_momx.o
# CC ../src/mon_momy.c ==> mon_momy.o
# CC ../src/mon_momz.c ==> mon_momz.o
# CC ../src/mon_torque.c ==> mon_torque.o
# CC ../src/comm_device.c ==> comm_device.o
# CC ../src/checkmute_y.c ==> checkmute_y.o
# CC ../src/checkmute_z.c ==> checkmute_z.o
# CC ../src/mon_reynolds.c ==> mon_reynolds.o
# CC ../src/mon_maxwell.c ==> mon_maxwell.o
# CC ../src/mon_bxflux.c ==> mon_bxflux.o
# CC ../src/postrestarthook.c ==> postrestarthook.o
# CC ../src/change_arch.c ==> change_arch.o
# CC ../src/select_device.c ==> select_device.o
# CC ../src/redefoptions.c ==> redefoptions.o
# CC ../src/setuphook1.c ==> setuphook1.o
# CC ../src/fill_ghostsx.c ==> fill_ghostsx.o
# CC ../src/cfl_fluids_min.c ==> cfl_fluids_min.o
# CC ../src/colrate.c ==> colrate.o
# CC ../src/collisions.c ==> collisions.o
# CC ../src/resetfield.c ==> resetfield.o
# CC ../src/totaldens.c ==> totaldens.o
# CC ../src/floor.c ==> floor.o
# CC ../src/ShearingPeriodicBC.c ==> ShearingPeriodicBC.o
# CC ../src/summary.c ==> summary.o
# CC ../src/dust_diffusion_main.c ==> dust_diffusion_main.o
# CC ../src/dust_diffusion_core.c ==> dust_diffusion_core.o
# CC ../src/dust_diffusion_coefficients.c ==> dust_diffusion_coefficients.o
# CC ../src/copy_field.c ==> copy_field.o
# CC ../src/nimhd_hall_effect.c ==> nimhd_hall_effect.o
# CC ../src/nimhd_hall_effect_emfx.c ==> nimhd_hall_effect_emfx.o
# CC ../src/nimhd_hall_effect_emfy.c ==> nimhd_hall_effect_emfy.o
# CC ../src/nimhd_hall_effect_emfz.c ==> nimhd_hall_effect_emfz.o
# CC ../src/nimhd_hall_effect_updateB.c ==> nimhd_hall_effect_updateB.o
# CC ../src/nimhd_hall_effect_update_emfs.c ==> nimhd_hall_effect_update_emfs.o
# CC ../src/nimhd_hall_effect_coeff.c ==> nimhd_hall_effect_coeff.o
# CC ../src/nimhd_ambipolar_diffusion.c ==> nimhd_ambipolar_diffusion.o
# CC ../src/nimhd_ambipolar_diffusion_emfx.c ==> nimhd_ambipolar_diffusion_emfx.o
# CC ../src/nimhd_ambipolar_diffusion_emfy.c ==> nimhd_ambipolar_diffusion_emfy.o
# CC ../src/nimhd_ambipolar_diffusion_emfz.c ==> nimhd_ambipolar_diffusion_emfz.o
# CC ../src/nimhd_ambipolar_diffusion_coeff.c ==> nimhd_ambipolar_diffusion_coeff.o
# CC ../src/nimhd_ohmic_diffusion.c ==> nimhd_ohmic_diffusion.o
# CC ../src/nimhd_ohmic_diffusion_coeff.c ==> nimhd_ohmic_diffusion_coeff.o
# CC ../src/compute_jx.c ==> compute_jx.o
# CC ../src/compute_jy.c ==> compute_jy.o
# CC ../src/compute_jz.c ==> compute_jz.o
# CC ymin_bound_0.c ==> ymin_bound_0.o
# CC ymax_bound_0.c ==> ymax_bound_0.o
# CC zmin_bound_0.c ==> zmin_bound_0.o
# CC zmax_bound_0.c ==> zmax_bound_0.o
# CC ../src/mpi_dummy.c ==> mpi_dummy.o
#
# All objects are OK. Linking stage
#
#           FARGO3D SUMMARY:
#           ===============
#
# This built is SEQUENTIAL. Use "make para" to change that
#
#
# SETUP:      'mri-growth-sb'
# (Use "make SETUP=[valid_setup_string]" to change set up)
# (Use "make list" to see the list of setups implemented)
# (Use "make info" to see the current sticky build options)
#
# rm ymin_bound_0.c
# make[1]: Leaving directory '/home/jovyan/fargo3d/bin'

# %% [markdown]
# Before running the code, have a look at the initial condition file (setups/mri-growth-sb/condinit.c) and the parameters file (setups/mri-growth-sb/mri-growth-sb.par), which allows you to modify the parameters of the run.
#
# Any parameter there can also be changed at execution time through the flag "-o",
#
# e.g.:
#
#     ./fargo3d -o "dt=0.1 nx=32 ny=32" setups/mri-growth-sb/mri-growth-sb.par
#
# #### Comment about the initial condition
#
# In the file "condinit.c", the eigenvectors are initialized proportional to trigonometric functions with argument $\left(2\pi z/\Delta Z\right)$, with $\Delta Z = Z_\text{max}-Z_\text{min}$. This is equivalent to considering the wave number $k = 2\pi/\Delta Z$. So, in order to change the excited mode, it is enough to change the vertical size of the box.
#
# The size $\Delta Z$ of the box is related to the wave number $k$ and the parameters of the problem by the following relation:
#
# \begin{equation}
# k = \frac{2\pi}{\Delta Z} = \frac{\tilde{k} \Omega_0}{v_{\rm A}} \Longrightarrow \Delta Z = \frac{2\pi v_{\rm A}}{\tilde{k}  \Omega_0}.
# \end{equation}
#
# With the default values provided in the setup, $v_A \simeq 0.003162$, so the maximum growth rate occur (at $\tilde{k}_{\text{max}} = \sqrt{15}/4$) at:
#
# \begin{equation}
# \Delta Z_\text{max} \simeq 0.0205
# \end{equation}
#
# which is the default "Zmax" value in the parameters file.
#
# Thus, in order to measure the dispersion relation, we will only modify the vertical extension of the box Zmax.

# %% [markdown]
# ------------

# %% [markdown]
# #### Step 2 - Running the code with the new setup

# %%
# !make #just in case you have modified some source file
# !./fargo3d -o "dt=0.1 zmax=0.0205 ny=32 nz=32" setups/mri-growth-sb/mri-growth-sb.par
# Out:
# make[1]: Entering directory '/home/jovyan/fargo3d/bin'
# make[1]: '../src/rescale.c' is up to date.
# make[1]: Leaving directory '/home/jovyan/fargo3d/bin'
# make[1]: Entering directory '/home/jovyan/fargo3d/bin'
#
#           FARGO3D SUMMARY:
#           ===============
#
# This built is SEQUENTIAL. Use "make para" to change that
#
#
# SETUP:      'mri-growth-sb'
# (Use "make SETUP=[valid_setup_string]" to change set up)
# (Use "make list" to see the list of setups implemented)
# (Use "make info" to see the current sticky build options)
#
# make[1]: Leaving directory '/home/jovyan/fargo3d/bin'
#
#        !!!! WARNING !!!!
#
# This is a sequential built of the ./fargo3d code
# If you planned to run the MPI-parallel version,
# then you MUST rebuild the executable. In this case,
#  issue:
# make PARALLEL=1 (or make para)
#
# Any subsequent invocation of make will build an MPI version.
#
#
# ===========================
# FARGO3D git version 2.0-16-gceef70c6
# SETUP: 'mri-growth-sb'
# ===========================
#
# The default output directory root is ./
# Reading parameters file setups/mri-growth-sb/mri-growth-sb.par
# Warning : NY is redefined on the command line.
# Warning : NZ is redefined on the command line.
# Warning : ZMAX is redefined on the command line.
# Warning : DT is redefined on the command line.
# The output directory is outputs/mri-growth-sb/
# Process 0 created the directory outputs/mri-growth-sb/
# I do not output the ghost values
# Warning: The Y spacing is linear (default).
# Field2D Reduction2D has been created
# Field Moment_Plus_X has been created
# Field Moment_Minus_X has been created
# Field2D Vxhy has been created
# Field2D Vxhyr has been created
# Field2D Vxhz has been created
# Field2D Vxhzr has been created
# Field2D Nshift has been created
# Field2D Nxhy has been created
# Field2D Nxhz has been created
# Field Moment_Plus_Y has been created
# Field Moment_Minus_Y has been created
# Field Moment_Plus_Z has been created
# Field Moment_Minus_Z has been created
# Field potential has been created
# Field Slope has been created
# Field DivRho has been created
# Field DensStar has been created
# Field Qs has been created
# Field Pressure has been created
# Field Total_Density has been created
# Grids Pressure and QLeft share their storage
# Field QRight has been created
# Field bx has been created
# Field by has been created
# Field bz has been created
# Grids Moment_Plus_Y and B1_star share their storage
# Grids Moment_Minus_Z and B2_star share their storage
# Grids Pressure and V1_star share their storage
# Grids Moment_Minus_X and V2_star share their storage
# Grids Moment_Plus_X and Slope_b1 share their storage
# Grids Moment_Minus_Y and Slope_v1 share their storage
# Grids DensStar and Slope_b2 share their storage
# Grids Qs and Slope_v2 share their storage
# Grids Moment_Plus_Z and Emfx share their storage
# Grids Slope and Emfy share their storage
# Grids DivRho and Emfz share their storage
# Field divb has been created
# Field gasdens has been created
# Field gasenergy has been created
# Field2D VxMed has been created
# Field gasvx has been created
# Field Vx_temp has been created
# Field gasvy has been created
# Field Vy_temp has been created
# Field gasvz has been created
# Field Vz_temp has been created
#
# ==============================================
# You are computing the mode ktilde = 0.969228
# ==============================================
#
# Found 2 communicators
# Standard version with no ghost zones in X
# OUTPUTS 0 at date t = 0.000000 OK
# ...................
# OUTPUTS 1 at date t = 0.100000 OK
# ...................
# OUTPUTS 2 at date t = 0.200000 OK
# ...................
# OUTPUTS 3 at date t = 0.300000 OK
# ...................
# OUTPUTS 4 at date t = 0.400000 OK
# ...................
# OUTPUTS 5 at date t = 0.500000 OK
# ...................
# OUTPUTS 6 at date t = 0.600000 OK
# ...................
# OUTPUTS 7 at date t = 0.700000 OK
# ...................
# OUTPUTS 8 at date t = 0.800000 OK
# ...................
# OUTPUTS 9 at date t = 0.900000 OK
# ...................
# OUTPUTS 10 at date t = 1.000000 OK
# ...................
# OUTPUTS 11 at date t = 1.100000 OK
# ...................
# OUTPUTS 12 at date t = 1.200000 OK
# ...................
# OUTPUTS 13 at date t = 1.300000 OK
# ...................
# OUTPUTS 14 at date t = 1.400000 OK
# ...................
# OUTPUTS 15 at date t = 1.500000 OK
# ...................
# OUTPUTS 16 at date t = 1.600000 OK
# ...................
# OUTPUTS 17 at date t = 1.700000 OK
# ...................
# OUTPUTS 18 at date t = 1.800000 OK
# ...................
# OUTPUTS 19 at date t = 1.900000 OK
# ...................
# OUTPUTS 20 at date t = 2.000000 OK
# End of the simulation!

# %% [markdown]
# #### Step 3 - For fixed $y_0$, plot $B_x(y_0,z)$ for output numbers 5, 10, and 15 (in the same axis). Explain what you observe.
#
# Let's concentrate on the solution for the component $B_x$, which is:
#
# \begin{align}
# \delta b_x(z,t) \propto \cos{\left(kz\right)} e^{\omega t} \nonumber \\
# \end{align}
#
# Note that for this task, the proportionality factors are not important. Since the solution does not depend on $y$, we can just plot a cut along the $z$-direction. Furthermore, we can also anticipate what we should observe: a trigonometric function whose amplitude grows with time exponentially.
#
# Example of cut:
#
#     get_data("bx",3,params)[:,params.ny//2]

# %%
params = Parameters("outputs/mri-growth-sb/")

fig, ax=plt.subplots(figsize=(9,9))
density = get_data("bx",10,params)
extent  = [params.ymin,params.ymax,params.zmin,params.zmax]
ax.imshow(density,extent=extent)
ax.set_xlabel("Y")
ax.set_ylabel("Z")
plt.show()

# %%
for i in [5,10,15]:
    cutx=get_data("bx",i,params)[:,params.ny//2]
    plt.plot(cutx)
plt.xlabel("Z")
plt.ylabel("bx")
plt.show()

# %% [markdown]
# We see that this quickly grows very large

# %% [markdown]
# ---------------

# %% [markdown]
# #### Step 4 - Using $B_x$, measure the growth-rate $\omega$ for the results from step2. Plot the value measured on top of the dispersion relation obtained analitically.
#
# Tip 1:
#
# The solution is of the form:
# \begin{align}
# \delta b_x(z,t) \propto \cos{\left(kz\right)} e^{\omega t} \nonumber
# \end{align}
#
# so, if we fix $z=z_0$:
# \begin{align}
# \delta b_x(z_0,t) = C e^{\omega t} \nonumber
# \end{align}
#
# with $C$ a constant, i.e., the perturbation must growth exponentially.
#
# Now, we can calculate:
#
# \begin{equation}
# \log|\delta b_x (z_0,t)| = \omega t + \log(C)
# \end{equation}
#
# Previous expression shows that we can measure the growth rate by plotting $\log(\delta b_x)$ ($B_x$ in our setup) as a function of time, which is a straight line. Furthermore, we can use a simple linear regresion to determine the slope (growth rate) from our data. (Check the function np.polyfit())
#
# Tip 2: The time corresponding to each output can be obtained as:
#
#     time = params.dt * params.ninterm * i
#
# where i is the output number

# %%
params = Parameters("outputs/mri-growth-sb/")

# We store the data in two lists    
by   = []
time = []

for i in range(20):
    time.append(i/10)
    by.append(get_data("bx",i,params)[params.nz//2,params.nx//2])

# We convert the lists to arrays so we can use numpy to modify them (if needed)
time = np.array(time)
by   = np.array(by)
logby =np.log(np.abs(by))
# And plot it
plt.plot(time,logby)
plt.show()

# %% [markdown]
# Now, we can use np.polyfit to obtain the slope of the curve

# %%
# Polyfit gives us the coefficients of the polynomial a*x+b
a,b = np.polyfit(time,logby, 1) 

x = np.linspace(time.min(),time.max(),100) # We create a domain array
y = a*x+b                                  # This is our fit

# And finally compare our fit with the data
plt.plot(time,np.log(np.abs(by)),'o',label='data')
plt.plot(x,y,'k--',label='fit')
plt.legend()
plt.show()

# %% [markdown]
# As we can see, the fit is excellent! Now, we can plot the measured growth rate (a) on top of our analytical dispersion relation:

# %%
# This is the dispersion relation

k_tilde = np.linspace(0,np.sqrt(3),100)
omega_unstable = np.sqrt(-0.5*(1 + 2*k_tilde**2) + 0.5*np.sqrt(1+16*k_tilde**2))
plt.plot(k_tilde,omega_unstable)

# And now we plot the measured value
k_tilde_experiment = np.sqrt(15)/4.0
omega_experiment = a

plt.plot(k_tilde_experiment,omega_experiment,'ko')

# %% [markdown]
# #### Step 5 - Determine the growth rate for all these values:
#
# $\Delta Z$ = [0.0911,  0.0514,  0.0358,  0.0274 ,	0.0223,  0.0188,  0.0162,  0.0142 ,  0.0127] and plot the pairs (${\tilde k},\omega$) for all the cases in one figure, on top of the analytical solution (as done above).
#
# For each run, you can obtain the corresponding $\tilde{k}$ from the terminal. Tip: in order to save time (and minimize the probability of typos), the lines needed to run the code can be generated automatically using strings.

# %%
cd ~/fargo3d
# Out:
# /home/jovyan/fargo3d

# %%
import os
Dz = np.array([0.0911, 0.0514, 0.0358, 
      0.0274, 0.0223, 0.0188, 
      0.0162, 0.0142, 0.0127])
k=2*np.pi/Dz
w_fits=[]
# If you have time, you can play with different number of cells
# but the default for the exercise is 32.
ny      = 32  #Number of cells in the radial direction
nz      = 32  #Number of cells in the vertical direction
dt      = 0.2 #Time between outputs

for i,delta_z in enumerate(Dz):
    arguments = '"zmax={0:4.4f} outputdir=outputs/output{1:d} ny={2:d} nz={3:d} dt={4:2.2f}"'.format(delta_z,i, ny, nz, dt)
    exec_line = "./fargo3d -o "+arguments+" setups/mri-growth-sb/mri-growth-sb.par"
#     !./fargo3d -o "+arguments+" setups/mri-growth-sb/mri-growth-sb.par
    print(exec_line)
    os.system(exec_line)
    by   = []
    time = []
    params = Parameters(f"outputs/output{i}")
    for j in range(20):
        time.append(dt*j)
        by.append(get_data("bx",j,params)[params.nz//2,params.nx//2])

#     We convert the lists to arrays so we can use numpy to modify them (if needed)
    time = np.array(time)
    by   = np.array(by)
    logby =np.log(np.abs(by))
    a,b = np.polyfit(time,logby, 1)
    w_fits.append(a)
    print(a)
# Out:
# ./fargo3d -o "zmax=0.0911 outputdir=outputs/output0 ny=32 nz=32 dt=0.20" setups/mri-growth-sb/mri-growth-sb.par
# ./fargo3d -o "zmax=0.0514 outputdir=outputs/output1 ny=32 nz=32 dt=0.20" setups/mri-growth-sb/mri-growth-sb.par
# ./fargo3d -o "zmax=0.0358 outputdir=outputs/output2 ny=32 nz=32 dt=0.20" setups/mri-growth-sb/mri-growth-sb.par
# ./fargo3d -o "zmax=0.0274 outputdir=outputs/output3 ny=32 nz=32 dt=0.20" setups/mri-growth-sb/mri-growth-sb.par
# ./fargo3d -o "zmax=0.0223 outputdir=outputs/output4 ny=32 nz=32 dt=0.20" setups/mri-growth-sb/mri-growth-sb.par
# ./fargo3d -o "zmax=0.0188 outputdir=outputs/output5 ny=32 nz=32 dt=0.20" setups/mri-growth-sb/mri-growth-sb.par
# ./fargo3d -o "zmax=0.0162 outputdir=outputs/output6 ny=32 nz=32 dt=0.20" setups/mri-growth-sb/mri-growth-sb.par
# ./fargo3d -o "zmax=0.0142 outputdir=outputs/output7 ny=32 nz=32 dt=0.20" setups/mri-growth-sb/mri-growth-sb.par
# ./fargo3d -o "zmax=0.0127 outputdir=outputs/output8 ny=32 nz=32 dt=0.20" setups/mri-growth-sb/mri-growth-sb.par

# %%
w_fits
# Out:
# [0.3376985805350481,
#  0.5210635398333586,
#  0.6410936643037987,
#  0.7145128565787014,
#  0.7482574811119365,
#  0.7474254439939705,
#  0.7093381361981834,
#  0.6239761938127841,
#  0.47522228503066294]

# %%
# This is the dispersion relation
k_tilde = np.linspace(0,np.sqrt(3),100)
omega_unstable = np.sqrt(-0.5*(1 + 2*k_tilde**2) + 0.5*np.sqrt(1+16*k_tilde**2))
plt.plot(k_tilde,omega_unstable)

# And now we plot the measured value
k_tilde_experiment = k*0.003162
omega_experiment = w_fits

plt.plot(k_tilde_experiment,omega_experiment,'ko')

# %% [markdown]
# ## Answers
#
# OT-test:
#
# Task 1:
# See above. Absolutely stunningly beautiful stuff
#
# Task 2:
# See above. Here we see that different parts of the gas are dominated by Magnetic/Velocity field, e.g. the center is dominated by streamlines while the two blobs north/south of the center are dominated by the magnetic field lines.
#
# Task 3: The colourbar scale is 1e-15 so I take this as being close to zero. Notice that the way Pablo has written Fargo, the code actually requires ${B_y}_{jk}-{B_y}_{j+1k} + {B_z}_{jk}-{B_z}_{jk+1} = 0$, because of the different face-scheme
#
# Linear MRI Test
#
# Task 1: Taking the first derivative of the given dispersion relation (see above) with respect to and setting it to zero, we get the equation $k^2-15/16=0$, which renders $\tilde{k}_\text{max} = \pm \sqrt{15}/4$, but we have k^2 in the equation, so physically the plus/minus are the same, so we choose the plus for simplicity.
# The $\omega_{max}=3/4$ comes from inserting $k_{max}$ into the dispersion relation.
# Both are plotted with the dispersion relation
# The cutoff occurs since $ \left[ -\frac{1 + 2\tilde{k}^2}{2} + \frac{1}{2}\sqrt{1+16\tilde{k}^{2}}\right]^{1/2}$ becomes $\left[ -\frac{7}{2} + \frac{7}{2}\right]^{1/2}=0$, and any k larger than this results in a negative number whose square root will be imaginary.
#
# Task 2:
#
# Step1/Step2 can be seen in code
#
# Step3: See cosine plot with multiple cosines growing (blue is 5, orange 10, green 15)
#
# Step4/5:
# See the plots in the above code. In step 5, the first and last points don’t hit perfectly but it’s still pretty good
